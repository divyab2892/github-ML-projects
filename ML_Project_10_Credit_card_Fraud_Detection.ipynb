# %% [markdown]
# <a href="https://colab.research.google.com/github/divyab2892/githubprojects/blob/main/ML_Project_10_Credit_card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Processing

# %%
#loading the dataset into pandas Dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#first 5 rows of Dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
#last 5 rows of dataset
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 43659  41598 -0.538686 -0.635328 -0.041569  ...  0.051010  0.072416   60.01    0.0
# 43660  41599 -0.349615 -2.860571  0.297766  ... -0.144908  0.125368  745.56    0.0
# 43661  41599 -3.001222  2.899766  0.726874  ...  1.184716  0.491066    8.99    0.0
# 43662  41599  1.042342 -0.390001 -0.463680  ...  0.035590 -0.008304   48.00    0.0
# 43663  41600  1.193909  0.067328  0.609239  ...       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
#number of rows and columns in dataset
credit_card_data.shape
# Out:
# (43664, 31)

# %%
#Dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43664 entries, 0 to 43663
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    43664 non-null  int64
#  1   V1      43664 non-null  float64
#  2   V2      43664 non-null  float64
#  3   V3      43664 non-null  float64
#  4   V4      43664 non-null  float64
#  5   V5      43664 non-null  float64
#  6   V6      43664 non-null  float64
#  7   V7      43664 non-null  float64
#  8   V8      43664 non-null  float64
#  9   V9      43664 non-null  float64
#  10  V10     43664 non-null  float64
#  11  V11     43664 non-null  float64
#  12  V12     43664 non-null  float64
#  13  V13     43664 non-null  float64
#  14  V14     43664 non-null  float64
#  15  V15     43664 non-null  float64
#  16  V16     43664 non-null  float64
#  17  V17     43664 non-null  float64
#  18  V18     43664 non-null  float64
#  19  V19     43664 non-null  float64
#  20  V20     43664 non-null  float64
#  21  V21     43664 non-null  float64
#  22  V22     43664 non-null  float64
#  23  V23     43664 non-null  float64
#  24  V24     43664 non-null  float64
#  25  V25     43664 non-null  float64
#  26  V26     43664 non-null  float64
#  27  V27     43663 non-null  float64
#  28  V28     43663 non-null  float64
#  29  Amount  43663 non-null  float64
#  30  Class   43663 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 10.3 MB

# %%
#Checking number of missing values in the dataset
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#distribution of legit transactions and Fradulent Transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    43529
# 1.0      134
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> Fradulent Transaction

# %%
#seperating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print (legit.shape, fraud.shape)
# Out:
# (43529, 31) (134, 31)

# %%
#statistical measures of data
legit.Amount.describe()
# Out:
# count    43529.000000
# mean        90.302800
# std        238.465356
# min          0.000000
# 25%          7.580000
# 50%         24.900000
# 75%         81.400000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     134.000000
# mean       93.928433
# std       231.551248
# min         0.000000
# 25%         1.000000
# 50%         6.455000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28     Amount
# Class                                    ...
# 0.0    26892.929610 -0.210136  0.014404  ...  0.004776  0.004927  90.302800
# 1.0    25259.246269 -7.759814  5.619386  ...  0.687503  0.063472  93.928433
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 32974  37037  0.969684 -0.442745  1.004656  ...  0.083066 -0.000795   11.50    0.0
# 31585  36423  1.161063  0.484868 -0.071030  ...  0.041055  0.049855    1.00    0.0
# 34531  37712  1.383729 -1.182432  0.991276  ...  0.066772  0.021117   16.00    0.0
# 18984  29930 -0.434112  1.079293  1.406730  ...  0.242918  0.092819    9.63    0.0
# 23994  33016 -0.073151 -0.599728  1.325434  ...  0.066498  0.028634   15.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time         V1        V2         V3  ...       V27       V28  Amount  Class
# 43061  41353 -15.020981  8.075240 -16.298091  ... -1.310888 -0.707403   34.12    1.0
# 43160  41397 -14.970346  8.401421 -16.867238  ... -1.621386 -1.104819  273.01    1.0
# 43204  41413 -15.140450  7.378042 -16.356367  ... -2.458680 -1.189888  106.55    1.0
# 43428  41505 -16.526507  8.584972 -18.649853  ... -2.018575 -1.042804  364.19    1.0
# 43624  41582  -1.048005  1.300219  -0.180401  ...  0.504898  0.069882   39.45    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    134
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2  ...       V27       V28     Amount
# Class                                    ...
# 0.0    26033.386179 -0.126435  0.053361  ...  0.015416 -0.000389  76.614309
# 1.0    25259.246269 -7.759814  5.619386  ...  0.687503  0.063472  93.928433
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the Data into Features and Target

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1        V2  ...       V27       V28  Amount
# 32974  37037   0.969684 -0.442745  ...  0.083066 -0.000795   11.50
# 31585  36423   1.161063  0.484868  ...  0.041055  0.049855    1.00
# 34531  37712   1.383729 -1.182432  ...  0.066772  0.021117   16.00
# 18984  29930  -0.434112  1.079293  ...  0.242918  0.092819    9.63
# 23994  33016  -0.073151 -0.599728  ...  0.066498  0.028634   15.00
# ...      ...        ...       ...  ...       ...       ...     ...
# 43061  41353 -15.020981  8.075240  ... -1.310888 -0.707403   34.12
# 43160  41397 -14.970346  8.401421  ... -1.621386 -1.104819  273.01
# 43204  41413 -15.140450  7.378042  ... -2.458680 -1.189888  106.55
# 43428  41505 -16.526507  8.584972  ... -2.018575 -1.042804  364.19
# 43624  41582  -1.048005  1.300219  ...  0.504898  0.069882   39.45
#
# [626 rows x 30 columns]

# %%
print(Y)
# Out:
# 32974    0.0
# 31585    0.0
# 34531    0.0
# 18984    0.0
# 23994    0.0
#         ...
# 43061    1.0
# 43160    1.0
# 43204    1.0
# 43428    1.0
# 43624    1.0
# Name: Class, Length: 626, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (626, 30) (500, 30) (126, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.984

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9603174603174603
